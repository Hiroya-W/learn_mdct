# %% [markdown]
# # 窓関数

# %% [markdown]
# Vorbis窓

# %% [markdown]
# $$
# {\omega_x = \sin(\frac{\pi}{2}\sin^{2}\pi x), 0 \leq x \leq 1
# }
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,1,1000)
y = np.sin(np.pi/2 * (np.sin(np.pi * x)**2))
plt.plot(x,y)
